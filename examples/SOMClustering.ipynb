# %% [markdown]
# # SOM clustering

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# --- for running the script without pip
import sys
sys.path.append("../")
# ---

import susi

# %% [markdown]
# ## Get data

# %%
X, y = make_blobs(n_samples=100, n_features=2, centers=3)
plt.scatter([x[0] for x in X], [x[1] for x in X])
plt.show()

# %% [markdown]
# ## Classify and plot

# %%
som = susi.SOMClustering()
som.fit(X)
print("SOM fitted!")
# Out:
# SOM fitted!

# %% [markdown]
# ## Plot u-Matrix

# %%
u_matrix = som.get_u_matrix()
plt.imshow(np.squeeze(u_matrix), cmap="Greys")
plt.colorbar()
plt.show()

# %% [markdown]
# ## Plot clusters

# %%
clusters = som.get_clusters(X)
plt.scatter(x=[c[0] for c in clusters], y=[c[1] for c in clusters], c=y, alpha=0.2)
plt.show()
